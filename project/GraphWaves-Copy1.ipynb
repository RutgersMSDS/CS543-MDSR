# %%
import os
import json
import pickle
import random 
import networkx as nx

import matplotlib
import matplotlib.pyplot as plt

from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %%
def plot_graph(g):
    plt.figure(3,figsize=(10,6))
    nx.draw_kamada_kawai(g, with_labels = True)

# %%
# computing max peel value for the input graph
def getMaxPeelValue(G, name="new"):
    
    G_copy = G.copy()

    iteration = 0
    peel_value = 0
    degrees = [val for (node, val) in G_copy.degree()]

    # plt.figure(figsize = (35, 45)) 

    while len(G_copy.nodes) > 0:
        iteration += 1
        fringe = G_copy.nodes
        fringe_degrees = [val for (node, val) in G_copy.degree()]

        # pick the vertices of minimum degree 
        min_degree = min(fringe_degrees)
        peel_value = max(peel_value, min_degree)
        min_degree_nodes = [node for index, node in enumerate(fringe) if G_copy.degree(node) == min_degree]

#         plt.subplot(920+iteration)
#         plt.title("-----Iteration :" + str(iteration) +
#                   "------\nMin degree = " + str(min_degree) +
#                   " \nMin degree Indices = {" + str(min_degree_nodes) +
#                   "} \nPeel Value = " + str(peel_value))

#         nx.draw_kamada_kawai(G_copy, with_labels = True)

        # remove the min degree vertices from fringe
        for node in min_degree_nodes:
            G_copy.remove_node(node)
    
    # plt.savefig("peelvalue/PeelValue-"+ name + str(iteration) +".png", format="PNG")
    return peel_value

# %%
def getWave(G, S0, P, name="1"):
    G_copy = G.copy()
    
    iteration = 0
    print("S 0 : ", S0)
    
    S = []
    edges_within_frag = []
    edge_fragments = []

    plt.figure(figsize = (20, 10))
    plt.set_cmap("viridis")
    
    G_wave = nx.Graph()
    while len(S0) > 0:
        iteration += 1
        S.append(S0)
        
        S1 = set()
        b_edges = []
        f_edges = []
        G_wave.add_nodes_from(S0)
        
        # Remove the Frag of S0 in G
        for node in S0:
            
            # E(G[S0])
            for node1 in S0:
                if (node1 in G_copy and 
                    node1 != node and 
                    (node1, node) in G_copy.edges() and
                    (node1, node) not in f_edges and
                    (node, node1) not in f_edges):
                    
                    G_copy.remove_edge(node, node1)
                    f_edges.append((node, node1))
            
            # BE(G[S0])
            for neighbor in E[node]:
                if node in G_copy and neighbor in G_copy:
                    
                    if neighbor not in S0:
                        S1.add(neighbor)
                        b_edges.append((node, neighbor))
                    
                    if (node, neighbor) in G_copy.edges():
                        G_copy.remove_edge(node, neighbor)

                    if(G_copy.degree(node) == 0):
                        G_copy.remove_node(node)

                    if(G_copy.degree(neighbor) == 0):
                        G_copy.remove_node(neighbor)
                        
                    elif(G_copy.degree(neighbor) > P):
                        S1.discard(neighbor)
        
            
        print("Boundary edges:", b_edges)       
        print("S", iteration, ":", S1)
        S0 = S1
        edges_within_frag.append(f_edges)
        if len(b_edges) > 0 and len(S0) > 0:
            edge_fragments.append(b_edges + f_edges)
            G_wave.add_edges_from(b_edges + f_edges)
            
    
    # Plot Wave
    if(len(G_wave.nodes()) > 0):
        plot_wave(name, G_wave, S, edges_within_frag, iteration)
    else:
        print("No nodes to plot in graph wave.")
        
        
    # Plot leftover G
    if(len(G_copy.nodes()) > 0):
        plot_graph(G_copy)
    else:
        print("No nodes to plot in leftover graph.")
    
    return [S, edge_fragments, G_wave, G_copy]


def plot_wave(name, G_wave, S, edges_within_frag, iteration):
    plt.title("-----Wave :" + name + "------\n")
    
    pos = nx.kamada_kawai_layout(G_wave, scale=0.5)
    viridis = cm.get_cmap('viridis', 12)
    for index in range(len(S)):
        #print("Ps: ", pos)
        new_pos = {key: pos[key] + [0, index*2] for key in pos}
        #print("Ps new: ", new_pos)
        
        edge_list = edges_within_frag[index] if index < len(edges_within_frag) else None
        new_color_map = [viridis(index * 0.3)] * len(S[index])
        
        nx.draw_networkx(G_wave,
                         new_pos,
                         with_labels = True,
                         font_color="white",
                         set_cmap="viridis",
                         nodelist=S[index],
                         edgelist=edge_list,
                         node_color=new_color_map)
    
    #plt.savefig("waves/Wave-"+ name + str(iteration) +".png", format="PNG")

# %%
def getGraphWithPeelValue(G, peelValue) : 
    G_core = G.copy()
    while True :
        for d in list(G_core.degree()) :
            if d[1] < peelValue :
                G_core.remove_node(d[0])
        if sorted(G_core.degree, key = lambda x: x[1])[0][1] >= peelValue : 
            return G_core

# %%
# I copied this one from above but I comment out code for plotting a graph
# computing max peel value for the input graph
def getMaxPeelValue(G, name="new"):
    
    G_copy = G.copy()

    iteration = 0
    peel_value = 0
    degrees = [val for (node, val) in G_copy.degree()]

    #plt.figure(figsize = (35, 45)) 

    while len(G_copy.nodes) > 0:
        iteration += 1
        fringe = G_copy.nodes
        fringe_degrees = [val for (node, val) in G_copy.degree()]

        # pick the vertices of minimum degree 
        min_degree = min(fringe_degrees)
        peel_value = max(peel_value, min_degree)
        min_degree_nodes = [node for index, node in enumerate(fringe) if G_copy.degree(node) == min_degree]

        #plt.subplot(920+iteration)
        #plt.title("-----Iteration :" + str(iteration) +
                 # "------\nMin degree = " + str(min_degree) +
                #  " \nMin degree Indices = {" + str(min_degree_nodes) +
                #  "} \nPeel Value = " + str(peel_value))

        #nx.draw_kamada_kawai(G_copy, with_labels = True)

        # remove the min degree vertices from fringe
        for node in min_degree_nodes:
            G_copy.remove_node(node)
    
    #plt.savefig("peelvalue/PeelValue-"+ name + str(iteration) +".png", format="PNG")
    return peel_value

# %%
def getRandomVerticesWithPeelValue(G, n, P) :
    node_list = set()
    
    if len(G.nodes()) == 0 : # if there is no nodes left
        return []
    
    v = [] # possible vertices 
    for d in list(G.degree()) :
        if d[1] <= P :
            v.append(d[0])
            
    if len(v) <= n : # if the number of nodes left is equal or less than n, return all satisfied nodes
        return v
        
    while True : # randomly pick n nodes
        node_list.add(random.choice(v))
        if len(node_list) == n :
            return list(node_list)

# %%
# getWave() without printing or drawing, and return only 2 objects
def getWave2(G, S0, P):
    G_copy = G.copy()
    
    S = []
    edges_within_frag = []
    edge_fragments = []
    
    G_wave = nx.Graph()
    while len(S0) > 0:
        S.append(list(S0))
        
        S1 = set()
        b_edges = []
        f_edges = []
        G_wave.add_nodes_from(S0)
        
        # Remove the Frag of S0 in G
        for node in S0:
            
            # E(G[S0])
            for node1 in S0:
                if (node1 in G_copy and 
                    node1 != node and 
                    (node1, node) in G_copy.edges() and
                    (node1, node) not in f_edges and
                    (node, node1) not in f_edges):
                    
                    G_copy.remove_edge(node, node1)
                    f_edges.append((node, node1))
            
            # BE(G[S0])
            for neighbor in G.neighbors(node):
                if node in G_copy and neighbor in G_copy:
                    
                    if neighbor not in S0:
                        S1.add(neighbor)
                        b_edges.append((node, neighbor))
                    
                    if (node, neighbor) in G_copy.edges():
                        G_copy.remove_edge(node, neighbor)

                    if(G_copy.degree(node) == 0):
                        G_copy.remove_node(node)

                    if(G_copy.degree(neighbor) == 0):
                        G_copy.remove_node(neighbor)
                        
                    elif(G_copy.degree(neighbor) > P):
                        S1.discard(neighbor)
                        
            
            # remove independent vertices
            if node in G_copy:
                G_copy.remove_node(node)
        
        # print("Wave: ", S0, " : ", S1, "\n--------------")
        S0 = S1
        
        edges_within_frag.append(f_edges)
        if len(b_edges) > 0 and len(S0) > 0:
            edge_fragments.append(b_edges + f_edges)
            G_wave.add_edges_from(b_edges + f_edges)

    return [G_wave, G_copy, S]

# %%
# getWave2(G,  [8, 13, 16, 19, 21], 4)

# %%
def getBuilding(G, P) :
    G_copy = G.copy()
    building = dict()
    
    counter_key = 1
    while True :
        S0 = getRandomVerticesWithPeelValue(G_copy, 5, P)
        
        if len(S0) == 0: 
            break
        
        wave, leftover_G, fragments = getWave2(G_copy, S0, P)
        # print("Building: ", wave.nodes(), " : ",leftover_G.nodes(), " : ", fragments, "\n--------------")
        if len(wave.nodes()) == 0 or len(fragments) == 0 : 
            break
        
        building[counter_key] = {"nodes": list(wave.nodes()), "edges": list(wave.edges()), "fragments": fragments} # add edges into building
        counter_key += 1
        
        G_copy = leftover_G
    
    return [building, G_copy]

# %%
# getBuilding(G, 4)

# %%
def getCity(G) :
    city = []
    G_copy = G.copy()
    
    while True :
        if G_copy.number_of_nodes() == 0 :
            break
        
        peelValue = getMaxPeelValue(G_copy)
        building, leftover_g = getBuilding(G_copy, peelValue)
        
        city.append(building)
        # print("City: ", city, "\n\n---------------")
        
        G_copy = leftover_g
    
    return city

# %%
# getCity(G)

# %%
input_folder = "/common/home/milky-way/temp/"

output_text_folder = "/common/home/milky-way/cities/"
output_image_folder = "/common/home/milky-way/output_images/"

def save_graph(g, filename):
    print("Saving image "+ filename + " ...")
    plt.figure(3,figsize=(20,20))
    nx.draw_kamada_kawai(g, with_labels = False)
    plt.savefig(output_image_folder + filename + ".png", format="PNG")
    
    print("Saved image: " + output_image_folder + filename + ".png")


def save_city_as_file(city, filename):
    print("Saving file "+ filename + " ...")
    with open(output_text_folder + filename + ".txt", 'w') as file:
         json.dump(city, file)
    
    print("Saved JSON: " + output_text_folder + filename + ".txt\n")


def build_star_tile_city(u, v, stars_tile_batch):
        star_u = int(u[1])
        star_v = int(v[1])

        if(not stars_tile_batch.has_node(star_u)):
            stars_tile_batch.add_node(star_u, info=u)

        if(not stars_tile_batch.has_node(star_v)):
            stars_tile_batch.add_node(star_v, info=v)

        if(not stars_tile_batch.has_edge(star_u, star_v)):
            stars_tile_batch.add_edge(star_u, star_v)
            
            
# file 2020-12-12 04:58:44.txt
def processStar(from_batch_filename):
    with open(input_folder + from_batch_filename) as f:
                stars_tile_batch = nx.Graph()
                
                for s in f:
                    u, v = [list(float(i) for i in el.strip('[]').split(', ')) for el in s.strip('()\n').split('], [')]
                    build_star_tile_city(u, v, stars_tile_batch)

                    
                
                star_tile_number = str(list(stars_tile_batch.nodes())[0])[: 3]
                
                
                    
                filename = star_tile_number + "_errored" 
                #save_graph(stars_tile_batch, filename)
                
                print("Processing: ", from_batch_filename, "\n\n", )
                
                cityJSON = {}
                cityJSON["data"] = getCity(stars_tile_batch)
                cityJSON["input_file"] = from_batch_filename
                
                
                save_city_as_file(cityJSON, filename)
              
                
def processAllStarTiles(folderpath):
    all_batch_files = os.listdir(folderpath)
    all_batch_files = sorted(all_batch_files, reverse=True)

    s_index = all_batch_files.index("2020-12-12 05:32:59.txt")
    end_index = all_batch_files.index("2020-12-12 05:16:24.txt") + 1
    all_batch_files = all_batch_files[s_index : end_index]
    
    star_tile_counter = {"208": 426, "213": 485, "212": 477, "211": 487, "210": 496, "209": 500}
    star_tile_number = None
    
    try :
        for from_batch_filename in all_batch_files :
         
            with open(input_folder + from_batch_filename) as f:
                stars_tile_batch = nx.Graph()
                
                for s in f:
                    u, v = [list(float(i) for i in el.strip('[]').split(', ')) for el in s.strip('()\n').split('], [')]
                    build_star_tile_city(u, v, stars_tile_batch)

                    
                counter = 500
                star_tile_number = str(list(stars_tile_batch.nodes())[0])[: 3]
                
                if star_tile_number in star_tile_counter:
                    counter = star_tile_counter[star_tile_number] - 1
                    star_tile_counter[star_tile_number] = counter
                else:
                    star_tile_counter[star_tile_number] = counter
                    
                filename = star_tile_number + "_" + str(counter)
                save_graph(stars_tile_batch, filename)
                
                print("Processing: ", from_batch_filename, "\n\n", )
                
                cityJSON = {}
                cityJSON["data"] = getCity(stars_tile_batch)
                cityJSON["input_file"] = from_batch_filename
                
                
                save_city_as_file(cityJSON, filename)
        
    except Exception as e:
        print("Got exception: ", e.with_traceback())


    finally:
        save_city_as_file(star_tile_counter, "Day4_Harshini")

# %%
processAllStarTiles(input_folder)
# processStar("2020-12-12 05:32:59.txt")
# Out:
# Saving image 213_484 ...
# Saved image: /common/home/milky-way/output_images/213_484.png
# Processing:  2020-12-12 05:32:59.txt
#
#
# Saving file 213_484 ...
# Saved JSON: /common/home/milky-way/cities/213_484.txt
#
# Saving image 213_483 ...
# Saved image: /common/home/milky-way/output_images/213_483.png
# Processing:  2020-12-12 05:32:54.txt
#
#
# Saving file 213_483 ...
# Saved JSON: /common/home/milky-way/cities/213_483.txt
#
# Saving image 213_482 ...
# Saved image: /common/home/milky-way/output_images/213_482.png
# Processing:  2020-12-12 05:32:53.txt
#
#
# Saving file 213_482 ...
# Saved JSON: /common/home/milky-way/cities/213_482.txt
#
# Saving image 213_481 ...
# Saved image: /common/home/milky-way/output_images/213_481.png
# Processing:  2020-12-12 05:32:52.txt
#
#
# Saving file 213_481 ...
# Saved JSON: /common/home/milky-way/cities/213_481.txt
#
# Saving image 213_480 ...
# Saved image: /common/home/milky-way/output_images/213_480.png
# Processing:  2020-12-12 05:32:51.txt
#
#
# Saving file 213_480 ...
# Saved JSON: /common/home/milky-way/cities/213_480.txt
#
# Saving image 213_479 ...
# Saved image: /common/home/milky-way/output_images/213_479.png
# Processing:  2020-12-12 05:32:50.txt
#
#
# Saving file 213_479 ...
# Saved JSON: /common/home/milky-way/cities/213_479.txt
#
# Saving image 213_478 ...
# Saved image: /common/home/milky-way/output_images/213_478.png
# Processing:  2020-12-12 05:32:49.txt
#
#
# Saving file 213_478 ...
# Saved JSON: /common/home/milky-way/cities/213_478.txt
#
# Saving image 213_477 ...
# Saved image: /common/home/milky-way/output_images/213_477.png
# Processing:  2020-12-12 05:32:48.txt
#
#
# Saving file 213_477 ...
# Saved JSON: /common/home/milky-way/cities/213_477.txt
#
# Saving image 213_476 ...
# Saved image: /common/home/milky-way/output_images/213_476.png
# Processing:  2020-12-12 05:32:47.txt
#
#
# Saving file 213_476 ...
# Saved JSON: /common/home/milky-way/cities/213_476.txt
#
# Saving image 213_475 ...
# Saved image: /common/home/milky-way/output_images/213_475.png
# Processing:  2020-12-12 05:32:46.txt
#
#
# Saving file 213_475 ...
# Saved JSON: /common/home/milky-way/cities/213_475.txt
#
# Saving image 213_474 ...
# Saved image: /common/home/milky-way/output_images/213_474.png
# Processing:  2020-12-12 05:32:45.txt
#
#
# Saving file 213_474 ...
# Saved JSON: /common/home/milky-way/cities/213_474.txt
#
# Saving image 213_473 ...
# Saved image: /common/home/milky-way/output_images/213_473.png
# Processing:  2020-12-12 05:32:44.txt
#
#
# Saving file 213_473 ...
# Saved JSON: /common/home/milky-way/cities/213_473.txt
#
# Saving image 213_472 ...
# Saved image: /common/home/milky-way/output_images/213_472.png
# Processing:  2020-12-12 05:32:43.txt
#
#
# Saving file 213_472 ...
# Saved JSON: /common/home/milky-way/cities/213_472.txt
#
# Saving image 213_471 ...
# Saved image: /common/home/milky-way/output_images/213_471.png
# Processing:  2020-12-12 05:32:42.txt
#
#
# Saving file 213_471 ...
# Saved JSON: /common/home/milky-way/cities/213_471.txt
#
# Saving image 213_470 ...
# Saved image: /common/home/milky-way/output_images/213_470.png
# Processing:  2020-12-12 05:32:41.txt
#
#
# Saving file 213_470 ...
# Saved JSON: /common/home/milky-way/cities/213_470.txt
#
# Saving image 213_469 ...
# Saved image: /common/home/milky-way/output_images/213_469.png
# Processing:  2020-12-12 05:32:40.txt
#
#
# Saving file 213_469 ...
# Saved JSON: /common/home/milky-way/cities/213_469.txt
#
# Saving image 213_468 ...
# Saved image: /common/home/milky-way/output_images/213_468.png
# Processing:  2020-12-12 05:32:39.txt
#
#
# Saving file 213_468 ...
# Saved JSON: /common/home/milky-way/cities/213_468.txt
#
# Saving image 213_467 ...
# Saved image: /common/home/milky-way/output_images/213_467.png
# Processing:  2020-12-12 05:32:38.txt
#
#
# Saving file 213_467 ...
# Saved JSON: /common/home/milky-way/cities/213_467.txt
#
# Saving image 213_466 ...
# Saved image: /common/home/milky-way/output_images/213_466.png
# Processing:  2020-12-12 05:32:37.txt
#
#
# Saving file 213_466 ...
# Saved JSON: /common/home/milky-way/cities/213_466.txt
#
# Saving image 213_465 ...
# Saved image: /common/home/milky-way/output_images/213_465.png
# Processing:  2020-12-12 05:32:36.txt
#
#
# Saving file 213_465 ...
# Saved JSON: /common/home/milky-way/cities/213_465.txt
#
# Saving image 213_464 ...
# Saved image: /common/home/milky-way/output_images/213_464.png
# Processing:  2020-12-12 05:32:35.txt
#
#
# Saving file 213_464 ...
# Saved JSON: /common/home/milky-way/cities/213_464.txt
#
# Saving image 213_463 ...
# Saved image: /common/home/milky-way/output_images/213_463.png
# Processing:  2020-12-12 05:32:34.txt
#
#
# Saving file 213_463 ...
# Saved JSON: /common/home/milky-way/cities/213_463.txt
#
# Saving image 213_462 ...
# Saved image: /common/home/milky-way/output_images/213_462.png
# Processing:  2020-12-12 05:32:33.txt
#
#
# Saving file 213_462 ...
# Saved JSON: /common/home/milky-way/cities/213_462.txt
#
# Saving image 213_461 ...
# Saved image: /common/home/milky-way/output_images/213_461.png
# Processing:  2020-12-12 05:32:31.txt
#
#
# Saving file 213_461 ...
# Saved JSON: /common/home/milky-way/cities/213_461.txt
#
# Saving image 213_460 ...
# Saved image: /common/home/milky-way/output_images/213_460.png
# Processing:  2020-12-12 05:32:30.txt
#
#
# Saving file 213_460 ...
# Saved JSON: /common/home/milky-way/cities/213_460.txt
#
# Saving image 213_459 ...
# Saved image: /common/home/milky-way/output_images/213_459.png
# Processing:  2020-12-12 05:32:28.txt
#
#
# Saving file 213_459 ...
# Saved JSON: /common/home/milky-way/cities/213_459.txt
#
# Saving image 213_458 ...
# Saved image: /common/home/milky-way/output_images/213_458.png
# Processing:  2020-12-12 05:32:27.txt
#
#
# Saving file 213_458 ...
# Saved JSON: /common/home/milky-way/cities/213_458.txt
#
# Saving image 213_457 ...
# Saved image: /common/home/milky-way/output_images/213_457.png
# Processing:  2020-12-12 05:32:26.txt
#
#
# Saving file 213_457 ...
# Saved JSON: /common/home/milky-way/cities/213_457.txt
#
# Saving image 213_456 ...
# Saved image: /common/home/milky-way/output_images/213_456.png
# Processing:  2020-12-12 05:32:25.txt
#
#
# Saving file 213_456 ...
# Saved JSON: /common/home/milky-way/cities/213_456.txt
#
# Saving image 213_455 ...
# Saved image: /common/home/milky-way/output_images/213_455.png
# Processing:  2020-12-12 05:32:24.txt
#
#
# Saving file 213_455 ...
# Saved JSON: /common/home/milky-way/cities/213_455.txt
#
# Saving image 213_454 ...
# Saved image: /common/home/milky-way/output_images/213_454.png
# Processing:  2020-12-12 05:32:23.txt
#
#
# Saving file 213_454 ...
# Saved JSON: /common/home/milky-way/cities/213_454.txt
#
# Saving image 213_453 ...
# Saved image: /common/home/milky-way/output_images/213_453.png
# Processing:  2020-12-12 05:32:22.txt
#
#
# Saving file 213_453 ...
# Saved JSON: /common/home/milky-way/cities/213_453.txt
#
# Saving image 213_452 ...
# Saved image: /common/home/milky-way/output_images/213_452.png
# Processing:  2020-12-12 05:32:21.txt
#
#
# Saving file 213_452 ...
# Saved JSON: /common/home/milky-way/cities/213_452.txt
#
# Saving image 213_451 ...
# Saved image: /common/home/milky-way/output_images/213_451.png
# Processing:  2020-12-12 05:32:20.txt
#
#
# Saving file 213_451 ...
# Saved JSON: /common/home/milky-way/cities/213_451.txt
#
# Saving image 213_450 ...
# Saved image: /common/home/milky-way/output_images/213_450.png
# Processing:  2020-12-12 05:32:18.txt
#
#
# Saving file 213_450 ...
# Saved JSON: /common/home/milky-way/cities/213_450.txt
#
# Saving image 213_449 ...
# Saved image: /common/home/milky-way/output_images/213_449.png
# Processing:  2020-12-12 05:32:17.txt
#
#
# Saving file 213_449 ...
# Saved JSON: /common/home/milky-way/cities/213_449.txt
#
# Saving image 213_448 ...
# Saved image: /common/home/milky-way/output_images/213_448.png
# Processing:  2020-12-12 05:32:16.txt
#
#
# Saving file 213_448 ...
# Saved JSON: /common/home/milky-way/cities/213_448.txt
#
# Saving image 213_447 ...
# Saved image: /common/home/milky-way/output_images/213_447.png
# Processing:  2020-12-12 05:32:15.txt
#
#
# Saving file 213_447 ...
# Saved JSON: /common/home/milky-way/cities/213_447.txt
#
# Saving image 213_446 ...
# Saved image: /common/home/milky-way/output_images/213_446.png
# Processing:  2020-12-12 05:32:14.txt
#
#
# Saving file 213_446 ...
# Saved JSON: /common/home/milky-way/cities/213_446.txt
#
# Saving image 213_445 ...
# Saved image: /common/home/milky-way/output_images/213_445.png
# Processing:  2020-12-12 05:32:12.txt
#
#
# Saving file 213_445 ...
# Saved JSON: /common/home/milky-way/cities/213_445.txt
#
# Saving image 213_444 ...
# Saved image: /common/home/milky-way/output_images/213_444.png
# Processing:  2020-12-12 05:32:11.txt
#
#
# Saving file 213_444 ...
# Saved JSON: /common/home/milky-way/cities/213_444.txt
#
# Saving image 213_443 ...
# Saved image: /common/home/milky-way/output_images/213_443.png
# Processing:  2020-12-12 05:32:10.txt
#
#
# Saving file 213_443 ...
# Saved JSON: /common/home/milky-way/cities/213_443.txt
#
# Saving image 213_442 ...
# Saved image: /common/home/milky-way/output_images/213_442.png
# Processing:  2020-12-12 05:32:09.txt
#
#
# Saving file 213_442 ...
# Saved JSON: /common/home/milky-way/cities/213_442.txt
#
# Saving image 213_441 ...
# Saved image: /common/home/milky-way/output_images/213_441.png
# Processing:  2020-12-12 05:32:08.txt
#
#
# Saving file 213_441 ...
# Saved JSON: /common/home/milky-way/cities/213_441.txt
#
# Saving image 213_440 ...
# Saved image: /common/home/milky-way/output_images/213_440.png
# Processing:  2020-12-12 05:32:07.txt
#
#
# Saving file 213_440 ...
# Saved JSON: /common/home/milky-way/cities/213_440.txt
#
# Saving image 213_439 ...
# Saved image: /common/home/milky-way/output_images/213_439.png
# Processing:  2020-12-12 05:32:06.txt
#
#
# Saving file 213_439 ...
# Saved JSON: /common/home/milky-way/cities/213_439.txt
#
# Saving image 213_438 ...
# Saved image: /common/home/milky-way/output_images/213_438.png
# Processing:  2020-12-12 05:32:05.txt
#
#
# Saving file 213_438 ...
# Saved JSON: /common/home/milky-way/cities/213_438.txt
#
# Saving image 213_437 ...
# Saved image: /common/home/milky-way/output_images/213_437.png
# Processing:  2020-12-12 05:32:04.txt
#
#
# Saving file 213_437 ...
# Saved JSON: /common/home/milky-way/cities/213_437.txt
#
# Saving image 213_436 ...
# Saved image: /common/home/milky-way/output_images/213_436.png
# Processing:  2020-12-12 05:32:03.txt
#
#
# Saving file 213_436 ...
# Saved JSON: /common/home/milky-way/cities/213_436.txt
#
# Saving image 213_435 ...
# Saved image: /common/home/milky-way/output_images/213_435.png
# Processing:  2020-12-12 05:32:02.txt
#
#
# Saving file 213_435 ...
# Saved JSON: /common/home/milky-way/cities/213_435.txt
#
# Saving image 213_434 ...
# Saved image: /common/home/milky-way/output_images/213_434.png
# Processing:  2020-12-12 05:32:01.txt
#
#
# Saving file 213_434 ...
# Saved JSON: /common/home/milky-way/cities/213_434.txt
#
# Saving image 213_433 ...
# Saved image: /common/home/milky-way/output_images/213_433.png
# Processing:  2020-12-12 05:32:00.txt
#
#
# Saving file 213_433 ...
# Saved JSON: /common/home/milky-way/cities/213_433.txt
#
# Saving image 213_432 ...
# Saved image: /common/home/milky-way/output_images/213_432.png
# Processing:  2020-12-12 05:31:59.txt
#
#
# Saving file 213_432 ...
# Saved JSON: /common/home/milky-way/cities/213_432.txt
#
# Saving image 213_431 ...
# Saved image: /common/home/milky-way/output_images/213_431.png
# Processing:  2020-12-12 05:31:58.txt
#
#
# Saving file 213_431 ...
# Saved JSON: /common/home/milky-way/cities/213_431.txt
#
# Saving image 213_430 ...
# Saved image: /common/home/milky-way/output_images/213_430.png
# Processing:  2020-12-12 05:31:57.txt
#
#
# Saving file 213_430 ...
# Saved JSON: /common/home/milky-way/cities/213_430.txt
#
# Saving image 213_429 ...
# Saved image: /common/home/milky-way/output_images/213_429.png
# Processing:  2020-12-12 05:31:56.txt
#
#
# Saving file 213_429 ...
# Saved JSON: /common/home/milky-way/cities/213_429.txt
#
# Saving image 213_428 ...
# Saved image: /common/home/milky-way/output_images/213_428.png
# Processing:  2020-12-12 05:31:55.txt
#
#
# Saving file 213_428 ...
# Saved JSON: /common/home/milky-way/cities/213_428.txt
#
# Saving image 213_427 ...
# Saved image: /common/home/milky-way/output_images/213_427.png
# Processing:  2020-12-12 05:31:54.txt
#
#
# Saving file 213_427 ...
# Saved JSON: /common/home/milky-way/cities/213_427.txt
#
# Saving image 213_426 ...
# Saved image: /common/home/milky-way/output_images/213_426.png
# Processing:  2020-12-12 05:31:53.txt
#
#
# Saving file 213_426 ...
# Saved JSON: /common/home/milky-way/cities/213_426.txt
#
# Saving image 213_425 ...
# Saved image: /common/home/milky-way/output_images/213_425.png
# Processing:  2020-12-12 05:31:52.txt
#
#
# Saving file 213_425 ...
# Saved JSON: /common/home/milky-way/cities/213_425.txt
#
# Saving image 213_424 ...
# Saved image: /common/home/milky-way/output_images/213_424.png
# Processing:  2020-12-12 05:31:51.txt
#
#
# Saving file 213_424 ...
# Saved JSON: /common/home/milky-way/cities/213_424.txt
#
# Saving image 213_423 ...
# Saved image: /common/home/milky-way/output_images/213_423.png
# Processing:  2020-12-12 05:31:50.txt
#
#
# Saving file 213_423 ...
# Saved JSON: /common/home/milky-way/cities/213_423.txt
#
# Saving image 213_422 ...
# Saved image: /common/home/milky-way/output_images/213_422.png
# Processing:  2020-12-12 05:31:49.txt
#
#
# Saving file 213_422 ...
# Saved JSON: /common/home/milky-way/cities/213_422.txt
#
# Saving image 213_421 ...
# Saved image: /common/home/milky-way/output_images/213_421.png
# Processing:  2020-12-12 05:31:48.txt
#
#
# Saving file 213_421 ...
# Saved JSON: /common/home/milky-way/cities/213_421.txt
#
# Saving image 213_420 ...
# Saved image: /common/home/milky-way/output_images/213_420.png
# Processing:  2020-12-12 05:31:47.txt
#
#
# Saving file 213_420 ...
# Saved JSON: /common/home/milky-way/cities/213_420.txt
#
# Saving image 213_419 ...
# Saved image: /common/home/milky-way/output_images/213_419.png
# Processing:  2020-12-12 05:31:46.txt
#
#
# Saving file 213_419 ...
# Saved JSON: /common/home/milky-way/cities/213_419.txt
#
# Saving image 213_418 ...
# Saved image: /common/home/milky-way/output_images/213_418.png
# Processing:  2020-12-12 05:31:44.txt
#
#
# Saving file 213_418 ...
# Saved JSON: /common/home/milky-way/cities/213_418.txt
#
# Saving image 213_417 ...
# Saved image: /common/home/milky-way/output_images/213_417.png
# Processing:  2020-12-12 05:31:43.txt
#
#
# Saving file 213_417 ...
# Saved JSON: /common/home/milky-way/cities/213_417.txt
#
# Saving image 213_416 ...
# Saved image: /common/home/milky-way/output_images/213_416.png
# Processing:  2020-12-12 05:31:42.txt
#
#
# Saving file 213_416 ...
# Saved JSON: /common/home/milky-way/cities/213_416.txt
#
# Saving image 213_415 ...
# Saved image: /common/home/milky-way/output_images/213_415.png
# Processing:  2020-12-12 05:31:41.txt
#
#
# Saving file 213_415 ...
# Saved JSON: /common/home/milky-way/cities/213_415.txt
#
# Saving image 213_414 ...
# Saved image: /common/home/milky-way/output_images/213_414.png
# Processing:  2020-12-12 05:31:40.txt
#
#
# Saving file 213_414 ...
# Saved JSON: /common/home/milky-way/cities/213_414.txt
#
# Saving image 213_413 ...
# Saved image: /common/home/milky-way/output_images/213_413.png
# Processing:  2020-12-12 05:31:39.txt
#
#
# Saving file 213_413 ...
# Saved JSON: /common/home/milky-way/cities/213_413.txt
#
# Saving image 213_412 ...
# Saved image: /common/home/milky-way/output_images/213_412.png
# Processing:  2020-12-12 05:31:38.txt
#
#
# Saving file 213_412 ...
# Saved JSON: /common/home/milky-way/cities/213_412.txt
#
# Saving image 213_411 ...
# Saved image: /common/home/milky-way/output_images/213_411.png
# Processing:  2020-12-12 05:31:37.txt
#
#
# Saving file 213_411 ...
# Saved JSON: /common/home/milky-way/cities/213_411.txt
#
# Saving image 213_410 ...
# Saved image: /common/home/milky-way/output_images/213_410.png
# Processing:  2020-12-12 05:31:36.txt
#
#
# Saving file 213_410 ...
# Saved JSON: /common/home/milky-way/cities/213_410.txt
#
# Saving image 213_409 ...
# Saved image: /common/home/milky-way/output_images/213_409.png
# Processing:  2020-12-12 05:31:35.txt
#
#
# Saving file 213_409 ...
# Saved JSON: /common/home/milky-way/cities/213_409.txt
#
# Saving image 213_408 ...
# Saved image: /common/home/milky-way/output_images/213_408.png
# Processing:  2020-12-12 05:31:34.txt
#
#
# Saving file 213_408 ...
# Saved JSON: /common/home/milky-way/cities/213_408.txt
#
# Saving image 213_407 ...
# Saved image: /common/home/milky-way/output_images/213_407.png
# Processing:  2020-12-12 05:31:33.txt
#
#
# Saving file 213_407 ...
# Saved JSON: /common/home/milky-way/cities/213_407.txt
#
# Saving image 213_406 ...
# Saved image: /common/home/milky-way/output_images/213_406.png
# Processing:  2020-12-12 05:31:32.txt
#
#
# Saving file 213_406 ...
# Saved JSON: /common/home/milky-way/cities/213_406.txt
#
# Saving image 213_405 ...
# Saved image: /common/home/milky-way/output_images/213_405.png
# Processing:  2020-12-12 05:31:31.txt
#
#
# Saving file 213_405 ...
# Saved JSON: /common/home/milky-way/cities/213_405.txt
#
# Saving image 213_404 ...
# Saved image: /common/home/milky-way/output_images/213_404.png
# Processing:  2020-12-12 05:31:30.txt
#
#
# Saving file 213_404 ...
# Saved JSON: /common/home/milky-way/cities/213_404.txt
#
# Saving image 213_403 ...
# Saved image: /common/home/milky-way/output_images/213_403.png
# Processing:  2020-12-12 05:31:29.txt
#
#
# Saving file 213_403 ...
# Saved JSON: /common/home/milky-way/cities/213_403.txt
#
# Saving image 213_402 ...
# Saved image: /common/home/milky-way/output_images/213_402.png
# Processing:  2020-12-12 05:31:28.txt
#
#
# Saving file 213_402 ...
# Saved JSON: /common/home/milky-way/cities/213_402.txt
#
# Saving image 213_401 ...
# Saved image: /common/home/milky-way/output_images/213_401.png
# Processing:  2020-12-12 05:31:27.txt
#
#
# Saving file 213_401 ...
# Saved JSON: /common/home/milky-way/cities/213_401.txt
#
# Saving image 213_400 ...
# Saved image: /common/home/milky-way/output_images/213_400.png
# Processing:  2020-12-12 05:31:26.txt
#
#
# Saving file 213_400 ...
# Saved JSON: /common/home/milky-way/cities/213_400.txt
#
# Saving image 213_399 ...
# Saved image: /common/home/milky-way/output_images/213_399.png
# Processing:  2020-12-12 05:31:25.txt
#
#
# Saving file 213_399 ...
# Saved JSON: /common/home/milky-way/cities/213_399.txt
#
# Saving image 213_398 ...
# Saved image: /common/home/milky-way/output_images/213_398.png
# Processing:  2020-12-12 05:31:24.txt
#
#
# Saving file 213_398 ...
# Saved JSON: /common/home/milky-way/cities/213_398.txt
#
# Saving image 212_476 ...
# Saved image: /common/home/milky-way/output_images/212_476.png
# Processing:  2020-12-12 05:31:23.txt
#
#
# Saving file 212_476 ...
# Saved JSON: /common/home/milky-way/cities/212_476.txt
#
# Saving image 212_475 ...
# Saved image: /common/home/milky-way/output_images/212_475.png
# Processing:  2020-12-12 05:31:22.txt
#
#
# Saving file 212_475 ...
# Saved JSON: /common/home/milky-way/cities/212_475.txt
#
# Saving image 212_474 ...
# Saved image: /common/home/milky-way/output_images/212_474.png
# Processing:  2020-12-12 05:31:21.txt
#
#
# Saving file 212_474 ...
# Saved JSON: /common/home/milky-way/cities/212_474.txt
#
# Saving image 212_473 ...
# Saved image: /common/home/milky-way/output_images/212_473.png
# Processing:  2020-12-12 05:31:20.txt
#
#
# Saving file 212_473 ...
# Saved JSON: /common/home/milky-way/cities/212_473.txt
#
# Saving image 212_472 ...
# Saved image: /common/home/milky-way/output_images/212_472.png
# Processing:  2020-12-12 05:31:19.txt
#
#
# Saving file 212_472 ...
# Saved JSON: /common/home/milky-way/cities/212_472.txt
#
# Saving image 212_471 ...
# Saved image: /common/home/milky-way/output_images/212_471.png
# Processing:  2020-12-12 05:31:18.txt
#
#
# Saving file 212_471 ...
# Saved JSON: /common/home/milky-way/cities/212_471.txt
#
# Saving image 212_470 ...
# Saved image: /common/home/milky-way/output_images/212_470.png
# Processing:  2020-12-12 05:31:17.txt
#
#
# Saving file 212_470 ...
# Saved JSON: /common/home/milky-way/cities/212_470.txt
#
# Saving image 212_469 ...
# Saved image: /common/home/milky-way/output_images/212_469.png
# Processing:  2020-12-12 05:31:16.txt
#
#
# Saving file 212_469 ...
# Saved JSON: /common/home/milky-way/cities/212_469.txt
#
# Saving image 212_468 ...
# Saved image: /common/home/milky-way/output_images/212_468.png
# Processing:  2020-12-12 05:31:14.txt
#
#
# Saving file 212_468 ...
# Saved JSON: /common/home/milky-way/cities/212_468.txt
#
# Saving image 212_467 ...
# Saved image: /common/home/milky-way/output_images/212_467.png
# Processing:  2020-12-12 05:31:13.txt
#
#
# Saving file 212_467 ...
# Saved JSON: /common/home/milky-way/cities/212_467.txt
#
# Saving image 212_466 ...
# Saved image: /common/home/milky-way/output_images/212_466.png
# Processing:  2020-12-12 05:31:12.txt
#
#
# Saving file 212_466 ...
# Saved JSON: /common/home/milky-way/cities/212_466.txt
#
# Saving image 212_465 ...
# Saved image: /common/home/milky-way/output_images/212_465.png
# Processing:  2020-12-12 05:31:11.txt
#
#
# Saving file 212_465 ...
# Saved JSON: /common/home/milky-way/cities/212_465.txt
#
# Saving image 212_464 ...
# Saved image: /common/home/milky-way/output_images/212_464.png
# Processing:  2020-12-12 05:31:10.txt
#
#
# Saving file 212_464 ...
# Saved JSON: /common/home/milky-way/cities/212_464.txt
#
# Saving image 212_463 ...
# Saved image: /common/home/milky-way/output_images/212_463.png
# Processing:  2020-12-12 05:31:09.txt
#
#
# Saving file 212_463 ...
# Saved JSON: /common/home/milky-way/cities/212_463.txt
#
# Saving image 212_462 ...
# Saved image: /common/home/milky-way/output_images/212_462.png
# Processing:  2020-12-12 05:31:08.txt
#
#
# Saving file 212_462 ...
# Saved JSON: /common/home/milky-way/cities/212_462.txt
#
# Saving image 212_461 ...
# Saved image: /common/home/milky-way/output_images/212_461.png
# Processing:  2020-12-12 05:31:07.txt
#
#
# Saving file 212_461 ...
# Saved JSON: /common/home/milky-way/cities/212_461.txt
#
# Saving image 212_460 ...
# Saved image: /common/home/milky-way/output_images/212_460.png
# Processing:  2020-12-12 05:31:06.txt
#
#
# Saving file 212_460 ...
# Saved JSON: /common/home/milky-way/cities/212_460.txt
#
# Saving image 212_459 ...
# Saved image: /common/home/milky-way/output_images/212_459.png
# Processing:  2020-12-12 05:31:05.txt
#
#
# Saving file 212_459 ...
# Saved JSON: /common/home/milky-way/cities/212_459.txt
#
# Saving image 212_458 ...
# Saved image: /common/home/milky-way/output_images/212_458.png
# Processing:  2020-12-12 05:31:04.txt
#
#
# Saving file 212_458 ...
# Saved JSON: /common/home/milky-way/cities/212_458.txt
#
# Saving image 212_457 ...
# Saved image: /common/home/milky-way/output_images/212_457.png
# Processing:  2020-12-12 05:31:03.txt
#
#
# Saving file 212_457 ...
# Saved JSON: /common/home/milky-way/cities/212_457.txt
#
# Saving image 212_456 ...
# Saved image: /common/home/milky-way/output_images/212_456.png
# Processing:  2020-12-12 05:31:01.txt
#
#
# Saving file 212_456 ...
# Saved JSON: /common/home/milky-way/cities/212_456.txt
#
# Saving image 212_455 ...
# Saved image: /common/home/milky-way/output_images/212_455.png
# Processing:  2020-12-12 05:31:00.txt
#
#
# Saving file 212_455 ...
# Saved JSON: /common/home/milky-way/cities/212_455.txt
#
# Saving image 212_454 ...
# Saved image: /common/home/milky-way/output_images/212_454.png
# Processing:  2020-12-12 05:30:59.txt
#
#
# Saving file 212_454 ...
# Saved JSON: /common/home/milky-way/cities/212_454.txt
#
# Saving image 212_453 ...
# Saved image: /common/home/milky-way/output_images/212_453.png
# Processing:  2020-12-12 05:30:58.txt
#
#
# Saving file 212_453 ...
# Saved JSON: /common/home/milky-way/cities/212_453.txt
#
# Saving image 212_452 ...
# Saved image: /common/home/milky-way/output_images/212_452.png
# Processing:  2020-12-12 05:30:57.txt
#
#
# Saving file 212_452 ...
# Saved JSON: /common/home/milky-way/cities/212_452.txt
#
# Saving image 212_451 ...
# Saved image: /common/home/milky-way/output_images/212_451.png
# Processing:  2020-12-12 05:30:56.txt
#
#
# Saving file 212_451 ...
# Saved JSON: /common/home/milky-way/cities/212_451.txt
#
# Saving image 212_450 ...
# Saved image: /common/home/milky-way/output_images/212_450.png
# Processing:  2020-12-12 05:30:55.txt
#
#
# Saving file 212_450 ...
# Saved JSON: /common/home/milky-way/cities/212_450.txt
#
# Saving image 212_449 ...
# Saved image: /common/home/milky-way/output_images/212_449.png
# Processing:  2020-12-12 05:30:54.txt
#
#
# Saving file 212_449 ...
# Saved JSON: /common/home/milky-way/cities/212_449.txt
#
# Saving image 212_448 ...
# Saved image: /common/home/milky-way/output_images/212_448.png
# Processing:  2020-12-12 05:30:53.txt
#
#
# Saving file 212_448 ...
# Saved JSON: /common/home/milky-way/cities/212_448.txt
#
# Saving image 212_447 ...
# Saved image: /common/home/milky-way/output_images/212_447.png
# Processing:  2020-12-12 05:30:52.txt
#
#
# Saving file 212_447 ...
# Saved JSON: /common/home/milky-way/cities/212_447.txt
#
# Saving image 212_446 ...
# Saved image: /common/home/milky-way/output_images/212_446.png
# Processing:  2020-12-12 05:30:51.txt
#
#
# Saving file 212_446 ...
# Saved JSON: /common/home/milky-way/cities/212_446.txt
#
# Saving image 212_445 ...
# Saved image: /common/home/milky-way/output_images/212_445.png
# Processing:  2020-12-12 05:30:50.txt
#
#
# Saving file 212_445 ...
# Saved JSON: /common/home/milky-way/cities/212_445.txt
#
# Saving image 212_444 ...
# Saved image: /common/home/milky-way/output_images/212_444.png
# Processing:  2020-12-12 05:30:49.txt
#
#
# Saving file 212_444 ...
# Saved JSON: /common/home/milky-way/cities/212_444.txt
#
# Saving image 212_443 ...
# Saved image: /common/home/milky-way/output_images/212_443.png
# Processing:  2020-12-12 05:30:48.txt
#
#
# Saving file 212_443 ...
# Saved JSON: /common/home/milky-way/cities/212_443.txt
#
# Saving image 212_442 ...
# Saved image: /common/home/milky-way/output_images/212_442.png
# Processing:  2020-12-12 05:30:47.txt
#
#
# Saving file 212_442 ...
# Saved JSON: /common/home/milky-way/cities/212_442.txt
#
# Saving image 212_441 ...
# Saved image: /common/home/milky-way/output_images/212_441.png
# Processing:  2020-12-12 05:30:46.txt
#
#
# Saving file 212_441 ...
# Saved JSON: /common/home/milky-way/cities/212_441.txt
#
# Saving image 212_440 ...
# Saved image: /common/home/milky-way/output_images/212_440.png
# Processing:  2020-12-12 05:30:45.txt
#
#
# Saving file 212_440 ...
# Saved JSON: /common/home/milky-way/cities/212_440.txt
#
# Saving image 212_439 ...
# Saved image: /common/home/milky-way/output_images/212_439.png
# Processing:  2020-12-12 05:30:44.txt
#
#
# Saving file 212_439 ...
# Saved JSON: /common/home/milky-way/cities/212_439.txt
#
# Saving image 212_438 ...
# Saved image: /common/home/milky-way/output_images/212_438.png
# Processing:  2020-12-12 05:30:43.txt
#
#
# Saving file 212_438 ...
# Saved JSON: /common/home/milky-way/cities/212_438.txt
#
# Saving image 212_437 ...
# Saved image: /common/home/milky-way/output_images/212_437.png
# Processing:  2020-12-12 05:30:42.txt
#
#
# Saving file 212_437 ...
# Saved JSON: /common/home/milky-way/cities/212_437.txt
#
# Saving image 212_436 ...
# Saved image: /common/home/milky-way/output_images/212_436.png
# Processing:  2020-12-12 05:30:33.txt
#
#
# Saving file 212_436 ...
# Saved JSON: /common/home/milky-way/cities/212_436.txt
#
# Saving image 212_435 ...
# Saved image: /common/home/milky-way/output_images/212_435.png
# Processing:  2020-12-12 05:30:28.txt
#
#
# Saving file 212_435 ...
# Saved JSON: /common/home/milky-way/cities/212_435.txt
#
# Saving image 212_434 ...
# Saved image: /common/home/milky-way/output_images/212_434.png
# Processing:  2020-12-12 05:30:27.txt
#
#
# Saving file 212_434 ...
# Saved JSON: /common/home/milky-way/cities/212_434.txt
#
# Saving image 212_433 ...
# Saved image: /common/home/milky-way/output_images/212_433.png
# Processing:  2020-12-12 05:30:26.txt
#
#
# Saving file 212_433 ...
# Saved JSON: /common/home/milky-way/cities/212_433.txt
#
# Saving image 212_432 ...
# Saved image: /common/home/milky-way/output_images/212_432.png
# Processing:  2020-12-12 05:30:25.txt
#
#
# Saving file 212_432 ...
# Saved JSON: /common/home/milky-way/cities/212_432.txt
#
# Saving image 212_431 ...
# Saved image: /common/home/milky-way/output_images/212_431.png
# Processing:  2020-12-12 05:30:23.txt
#
#
# Saving file 212_431 ...
# Saved JSON: /common/home/milky-way/cities/212_431.txt
#
# Saving image 212_430 ...
# Saved image: /common/home/milky-way/output_images/212_430.png
# Processing:  2020-12-12 05:30:22.txt
#
#
# Saving file 212_430 ...
# Saved JSON: /common/home/milky-way/cities/212_430.txt
#
# Saving image 212_429 ...
# Saved image: /common/home/milky-way/output_images/212_429.png
# Processing:  2020-12-12 05:30:21.txt
#
#
# Saving file 212_429 ...
# Saved JSON: /common/home/milky-way/cities/212_429.txt
#
# Saving image 212_428 ...
# Saved image: /common/home/milky-way/output_images/212_428.png
# Processing:  2020-12-12 05:30:17.txt
#
#
# Saving file 212_428 ...
# Saved JSON: /common/home/milky-way/cities/212_428.txt
#
# Saving image 212_427 ...
# Saved image: /common/home/milky-way/output_images/212_427.png
# Processing:  2020-12-12 05:30:16.txt
#
#
# Saving file 212_427 ...
# Saved JSON: /common/home/milky-way/cities/212_427.txt
#
# Saving image 212_426 ...
# Saved image: /common/home/milky-way/output_images/212_426.png
# Processing:  2020-12-12 05:30:13.txt
#
#
# Saving file 212_426 ...
# Saved JSON: /common/home/milky-way/cities/212_426.txt
#
# Saving image 212_425 ...
# Saved image: /common/home/milky-way/output_images/212_425.png
# Processing:  2020-12-12 05:30:12.txt
#
#
# Saving file 212_425 ...
# Saved JSON: /common/home/milky-way/cities/212_425.txt
#
# Saving image 212_424 ...
# Saved image: /common/home/milky-way/output_images/212_424.png
# Processing:  2020-12-12 05:30:11.txt
#
#
# Saving file 212_424 ...
# Saved JSON: /common/home/milky-way/cities/212_424.txt
#
# Saving image 212_423 ...
# Saved image: /common/home/milky-way/output_images/212_423.png
# Processing:  2020-12-12 05:30:10.txt
#
#
# Saving file 212_423 ...
# Saved JSON: /common/home/milky-way/cities/212_423.txt
#
# Saving image 212_422 ...
# Saved image: /common/home/milky-way/output_images/212_422.png
# Processing:  2020-12-12 05:30:09.txt
#
#
# Saving file 212_422 ...
# Saved JSON: /common/home/milky-way/cities/212_422.txt
#
# Saving image 212_421 ...
# Saved image: /common/home/milky-way/output_images/212_421.png
# Processing:  2020-12-12 05:30:08.txt
#
#
# Saving file 212_421 ...
# Saved JSON: /common/home/milky-way/cities/212_421.txt
#
# Saving image 212_420 ...
# Saved image: /common/home/milky-way/output_images/212_420.png
# Processing:  2020-12-12 05:30:07.txt
#
#
# Saving file 212_420 ...
# Saved JSON: /common/home/milky-way/cities/212_420.txt
#
# Saving image 212_419 ...
# Saved image: /common/home/milky-way/output_images/212_419.png
# Processing:  2020-12-12 05:30:06.txt
#
#
# Saving file 212_419 ...
# Saved JSON: /common/home/milky-way/cities/212_419.txt
#
# Saving image 212_418 ...
# Saved image: /common/home/milky-way/output_images/212_418.png
# Processing:  2020-12-12 05:30:05.txt
#
#
# Saving file 212_418 ...
# Saved JSON: /common/home/milky-way/cities/212_418.txt
#
# Saving image 212_417 ...
# Saved image: /common/home/milky-way/output_images/212_417.png
# Processing:  2020-12-12 05:30:04.txt
#
#
# Saving file 212_417 ...
# Saved JSON: /common/home/milky-way/cities/212_417.txt
#
# Saving image 212_416 ...
# Saved image: /common/home/milky-way/output_images/212_416.png
# Processing:  2020-12-12 05:30:03.txt
#
#
# Saving file 212_416 ...
# Saved JSON: /common/home/milky-way/cities/212_416.txt
#
# Saving image 212_415 ...
# Saved image: /common/home/milky-way/output_images/212_415.png
# Processing:  2020-12-12 05:30:02.txt
#
#
# Saving file 212_415 ...
# Saved JSON: /common/home/milky-way/cities/212_415.txt
#
# Saving image 212_414 ...
# Saved image: /common/home/milky-way/output_images/212_414.png
# Processing:  2020-12-12 05:30:01.txt
#
#
# Saving file 212_414 ...
# Saved JSON: /common/home/milky-way/cities/212_414.txt
#
# Saving image 212_413 ...
# Saved image: /common/home/milky-way/output_images/212_413.png
# Processing:  2020-12-12 05:29:58.txt
#
#
# Saving file 212_413 ...
# Saved JSON: /common/home/milky-way/cities/212_413.txt
#
# Saving image 212_412 ...
# Saved image: /common/home/milky-way/output_images/212_412.png
# Processing:  2020-12-12 05:29:57.txt
#
#
# Saving file 212_412 ...
# Saved JSON: /common/home/milky-way/cities/212_412.txt
#
# Saving image 212_411 ...
# Saved image: /common/home/milky-way/output_images/212_411.png
# Processing:  2020-12-12 05:29:52.txt
#
#
# Saving file 212_411 ...
# Saved JSON: /common/home/milky-way/cities/212_411.txt
#
# Saving image 212_410 ...
# Saved image: /common/home/milky-way/output_images/212_410.png
# Processing:  2020-12-12 05:29:48.txt
#
#
# Saving file 212_410 ...
# Saved JSON: /common/home/milky-way/cities/212_410.txt
#
# Saving image 212_409 ...
# Saved image: /common/home/milky-way/output_images/212_409.png
# Processing:  2020-12-12 05:29:43.txt
#
#
# Saving file 212_409 ...
# Saved JSON: /common/home/milky-way/cities/212_409.txt
#
# Saving image 212_408 ...
# Saved image: /common/home/milky-way/output_images/212_408.png
# Processing:  2020-12-12 05:29:37.txt
#
#
# Saving file 212_408 ...
# Saved JSON: /common/home/milky-way/cities/212_408.txt
#
# Saving image 212_407 ...
# Saved image: /common/home/milky-way/output_images/212_407.png
# Processing:  2020-12-12 05:29:32.txt
#
#
# Saving file 212_407 ...
# Saved JSON: /common/home/milky-way/cities/212_407.txt
#
# Saving image 212_406 ...
# Saved image: /common/home/milky-way/output_images/212_406.png
# Processing:  2020-12-12 05:29:31.txt
#
#
# Saving file 212_406 ...
# Saved JSON: /common/home/milky-way/cities/212_406.txt
#
# Saving image 212_405 ...
# Saved image: /common/home/milky-way/output_images/212_405.png
# Processing:  2020-12-12 05:29:30.txt
#
#
# Saving file 212_405 ...
# Saved JSON: /common/home/milky-way/cities/212_405.txt
#
# Saving image 212_404 ...
# Saved image: /common/home/milky-way/output_images/212_404.png
# Processing:  2020-12-12 05:29:27.txt
#
#
# Saving file 212_404 ...
# Saved JSON: /common/home/milky-way/cities/212_404.txt
#
# Saving image 212_403 ...
# Saved image: /common/home/milky-way/output_images/212_403.png
# Processing:  2020-12-12 05:29:21.txt
#
#
# Saving file 212_403 ...
# Saved JSON: /common/home/milky-way/cities/212_403.txt
#
# Saving image 212_402 ...
# Saved image: /common/home/milky-way/output_images/212_402.png
# Processing:  2020-12-12 05:29:19.txt
#
#
# Saving file 212_402 ...
# Saved JSON: /common/home/milky-way/cities/212_402.txt
#
# Saving image 212_401 ...
# Saved image: /common/home/milky-way/output_images/212_401.png
# Processing:  2020-12-12 05:29:18.txt
#
#
# Saving file 212_401 ...
# Saved JSON: /common/home/milky-way/cities/212_401.txt
#
# Saving image 212_400 ...
# Saved image: /common/home/milky-way/output_images/212_400.png
# Processing:  2020-12-12 05:29:15.txt
#
#
# Saving file 212_400 ...
# Saved JSON: /common/home/milky-way/cities/212_400.txt
#
# Saving image 212_399 ...
# Saved image: /common/home/milky-way/output_images/212_399.png
# Processing:  2020-12-12 05:29:13.txt
#
#
# Saving file 212_399 ...
# Saved JSON: /common/home/milky-way/cities/212_399.txt
#
# Saving image 212_398 ...
# Saved image: /common/home/milky-way/output_images/212_398.png
# Processing:  2020-12-12 05:29:07.txt
#
#
# Saving file 212_398 ...
# Saved JSON: /common/home/milky-way/cities/212_398.txt
#
# Saving image 212_397 ...
# Saved image: /common/home/milky-way/output_images/212_397.png
# Processing:  2020-12-12 05:28:58.txt
#
#
# Saving file 212_397 ...
# Saved JSON: /common/home/milky-way/cities/212_397.txt
#
# Saving image 212_396 ...
# Saved image: /common/home/milky-way/output_images/212_396.png
# Processing:  2020-12-12 05:28:54.txt
#
#
# Saving file 212_396 ...
# Saved JSON: /common/home/milky-way/cities/212_396.txt
#
# Saving image 212_395 ...
# Saved image: /common/home/milky-way/output_images/212_395.png
# Processing:  2020-12-12 05:28:46.txt
#
#
# Saving file 212_395 ...
# Saved JSON: /common/home/milky-way/cities/212_395.txt
#
# Saving image 212_394 ...
# Saved image: /common/home/milky-way/output_images/212_394.png
# Processing:  2020-12-12 05:28:40.txt
#
#
# Saving file 212_394 ...
# Saved JSON: /common/home/milky-way/cities/212_394.txt
#
# Saving image 212_393 ...
# Saved image: /common/home/milky-way/output_images/212_393.png
# Processing:  2020-12-12 05:28:39.txt
#
#
# Saving file 212_393 ...
# Saved JSON: /common/home/milky-way/cities/212_393.txt
#
# Saving image 212_392 ...
# Saved image: /common/home/milky-way/output_images/212_392.png
# Processing:  2020-12-12 05:28:38.txt
#
#
# Saving file 212_392 ...
# Saved JSON: /common/home/milky-way/cities/212_392.txt
#
# Saving image 212_391 ...
# Saved image: /common/home/milky-way/output_images/212_391.png
# Processing:  2020-12-12 05:28:37.txt
#
#
# Saving file 212_391 ...
# Saved JSON: /common/home/milky-way/cities/212_391.txt
#
# Saving image 212_390 ...
# Saved image: /common/home/milky-way/output_images/212_390.png
# Processing:  2020-12-12 05:28:36.txt
#
#
# Saving file 212_390 ...
# Saved JSON: /common/home/milky-way/cities/212_390.txt
#
# Saving image 212_389 ...
# Saved image: /common/home/milky-way/output_images/212_389.png
# Processing:  2020-12-12 05:28:35.txt
#
#
# Saving file 212_389 ...
# Saved JSON: /common/home/milky-way/cities/212_389.txt
#
# Saving image 212_388 ...
# Saved image: /common/home/milky-way/output_images/212_388.png
# Processing:  2020-12-12 05:28:29.txt
#
#
# Saving file 212_388 ...
# Saved JSON: /common/home/milky-way/cities/212_388.txt
#
# Saving image 211_486 ...
# Saved image: /common/home/milky-way/output_images/211_486.png
# Processing:  2020-12-12 05:28:18.txt
#
#
# Saving file 211_486 ...
# Saved JSON: /common/home/milky-way/cities/211_486.txt
#
# Saving image 211_485 ...
# Saved image: /common/home/milky-way/output_images/211_485.png
# Processing:  2020-12-12 05:28:10.txt
#
#
# Saving file 211_485 ...
# Saved JSON: /common/home/milky-way/cities/211_485.txt
#
# Saving image 211_484 ...
# Saved image: /common/home/milky-way/output_images/211_484.png
# Processing:  2020-12-12 05:28:07.txt
#
#
# Saving file 211_484 ...
# Saved JSON: /common/home/milky-way/cities/211_484.txt
#
# Saving image 211_483 ...
# Saved image: /common/home/milky-way/output_images/211_483.png
# Processing:  2020-12-12 05:28:06.txt
#
#
# Saving file 211_483 ...
# Saved JSON: /common/home/milky-way/cities/211_483.txt
#
# Saving image 211_482 ...
# Saved image: /common/home/milky-way/output_images/211_482.png
# Processing:  2020-12-12 05:28:00.txt
#
#
# Saving file 211_482 ...
# Saved JSON: /common/home/milky-way/cities/211_482.txt
#
# Saving image 211_481 ...
# Saved image: /common/home/milky-way/output_images/211_481.png
# Processing:  2020-12-12 05:27:55.txt
#
#
# Saving file 211_481 ...
# Saved JSON: /common/home/milky-way/cities/211_481.txt
#
# Saving image 211_480 ...
# Saved image: /common/home/milky-way/output_images/211_480.png
# Processing:  2020-12-12 05:27:40.txt
#
#
# Saving file 211_480 ...
# Saved JSON: /common/home/milky-way/cities/211_480.txt
#
# Saving image 211_479 ...
# Saved image: /common/home/milky-way/output_images/211_479.png
# Processing:  2020-12-12 05:27:33.txt
#
#
# Saving file 211_479 ...
# Saved JSON: /common/home/milky-way/cities/211_479.txt
#
# Saving image 211_478 ...
# Saved image: /common/home/milky-way/output_images/211_478.png
# Processing:  2020-12-12 05:27:28.txt
#
#
# Saving file 211_478 ...
# Saved JSON: /common/home/milky-way/cities/211_478.txt
#
# Saving image 211_477 ...
# Saved image: /common/home/milky-way/output_images/211_477.png
# Processing:  2020-12-12 05:27:20.txt
#
#
# Saving file 211_477 ...
# Saved JSON: /common/home/milky-way/cities/211_477.txt
#
# Saving image 211_476 ...
# Saved image: /common/home/milky-way/output_images/211_476.png
# Processing:  2020-12-12 05:27:08.txt
#
#
# Saving file 211_476 ...
# Saved JSON: /common/home/milky-way/cities/211_476.txt
#
# Saving image 211_475 ...
# Saved image: /common/home/milky-way/output_images/211_475.png
# Processing:  2020-12-12 05:27:07.txt
#
#
# Saving file 211_475 ...
# Saved JSON: /common/home/milky-way/cities/211_475.txt
#
# Saving image 211_474 ...
# Saved image: /common/home/milky-way/output_images/211_474.png
# Processing:  2020-12-12 05:26:57.txt
#
#
# Saving file 211_474 ...
# Saved JSON: /common/home/milky-way/cities/211_474.txt
#
# Saving image 211_473 ...
# Saved image: /common/home/milky-way/output_images/211_473.png
# Processing:  2020-12-12 05:26:55.txt
#
#
# Saving file 211_473 ...
# Saved JSON: /common/home/milky-way/cities/211_473.txt
#
# Saving image 211_472 ...
# Saved image: /common/home/milky-way/output_images/211_472.png
# Processing:  2020-12-12 05:26:53.txt
#
#
# Saving file 211_472 ...
# Saved JSON: /common/home/milky-way/cities/211_472.txt
#
# Saving image 211_471 ...
# Saved image: /common/home/milky-way/output_images/211_471.png
# Processing:  2020-12-12 05:26:52.txt
#
#
# Saving file 211_471 ...
# Saved JSON: /common/home/milky-way/cities/211_471.txt
#
# Saving image 211_470 ...
# Saved image: /common/home/milky-way/output_images/211_470.png
# Processing:  2020-12-12 05:26:51.txt
#
#
# Saving file 211_470 ...
# Saved JSON: /common/home/milky-way/cities/211_470.txt
#
# Saving image 211_469 ...
# Saved image: /common/home/milky-way/output_images/211_469.png
# Processing:  2020-12-12 05:26:46.txt
#
#
# Saving file 211_469 ...
# Saved JSON: /common/home/milky-way/cities/211_469.txt
#
# Saving image 211_468 ...
# Saved image: /common/home/milky-way/output_images/211_468.png
# Processing:  2020-12-12 05:26:43.txt
#
#
# Saving file 211_468 ...
# Saved JSON: /common/home/milky-way/cities/211_468.txt
#
# Saving image 211_467 ...
# Saved image: /common/home/milky-way/output_images/211_467.png
# Processing:  2020-12-12 05:26:38.txt
#
#
# Saving file 211_467 ...
# Saved JSON: /common/home/milky-way/cities/211_467.txt
#
# Saving image 211_466 ...
# Saved image: /common/home/milky-way/output_images/211_466.png
# Processing:  2020-12-12 05:26:23.txt
#
#
# Saving file 211_466 ...
# Saved JSON: /common/home/milky-way/cities/211_466.txt
#
# Saving image 211_465 ...
# Saved image: /common/home/milky-way/output_images/211_465.png
# Processing:  2020-12-12 05:26:21.txt
#
#
# Saving file 211_465 ...
# Saved JSON: /common/home/milky-way/cities/211_465.txt
#
# Saving image 211_464 ...
# Saved image: /common/home/milky-way/output_images/211_464.png
# Processing:  2020-12-12 05:26:15.txt
#
#
# Saving file 211_464 ...
# Saved JSON: /common/home/milky-way/cities/211_464.txt
#
# Saving image 211_463 ...
# Saved image: /common/home/milky-way/output_images/211_463.png
# Processing:  2020-12-12 05:26:14.txt
#
#
# Saving file 211_463 ...
# Saved JSON: /common/home/milky-way/cities/211_463.txt
#
# Saving image 211_462 ...
# Saved image: /common/home/milky-way/output_images/211_462.png
# Processing:  2020-12-12 05:26:04.txt
#
#
# Saving file 211_462 ...
# Saved JSON: /common/home/milky-way/cities/211_462.txt
#
# Saving image 211_461 ...
# Saved image: /common/home/milky-way/output_images/211_461.png
# Processing:  2020-12-12 05:26:02.txt
#
#
# Saving file 211_461 ...
# Saved JSON: /common/home/milky-way/cities/211_461.txt
#
# Saving image 211_460 ...
# Saved image: /common/home/milky-way/output_images/211_460.png
# Processing:  2020-12-12 05:26:00.txt
#
#
# Saving file 211_460 ...
# Saved JSON: /common/home/milky-way/cities/211_460.txt
#
# Saving image 211_459 ...
# Saved image: /common/home/milky-way/output_images/211_459.png
# Processing:  2020-12-12 05:25:59.txt
#
#
# Saving file 211_459 ...
# Saved JSON: /common/home/milky-way/cities/211_459.txt
#
# Saving image 211_458 ...
# Saved image: /common/home/milky-way/output_images/211_458.png
# Processing:  2020-12-12 05:25:58.txt
#
#
# Saving file 211_458 ...
# Saved JSON: /common/home/milky-way/cities/211_458.txt
#
# Saving image 211_457 ...
# Saved image: /common/home/milky-way/output_images/211_457.png
# Processing:  2020-12-12 05:25:54.txt
#
#
# Saving file 211_457 ...
# Saved JSON: /common/home/milky-way/cities/211_457.txt
#
# Saving image 211_456 ...
# Saved image: /common/home/milky-way/output_images/211_456.png
# Processing:  2020-12-12 05:25:53.txt
#
#
# Saving file 211_456 ...
# Saved JSON: /common/home/milky-way/cities/211_456.txt
#
# Saving image 211_455 ...
# Saved image: /common/home/milky-way/output_images/211_455.png
# Processing:  2020-12-12 05:25:44.txt
#
#
# Saving file 211_455 ...
# Saved JSON: /common/home/milky-way/cities/211_455.txt
#
# Saving image 211_454 ...
# Saved image: /common/home/milky-way/output_images/211_454.png
# Processing:  2020-12-12 05:25:39.txt
#
#
# Saving file 211_454 ...
# Saved JSON: /common/home/milky-way/cities/211_454.txt
#
# Saving image 211_453 ...
# Saved image: /common/home/milky-way/output_images/211_453.png
# Processing:  2020-12-12 05:25:38.txt
#
#
# Saving file 211_453 ...
# Saved JSON: /common/home/milky-way/cities/211_453.txt
#
# Saving image 211_452 ...
# Saved image: /common/home/milky-way/output_images/211_452.png
# Processing:  2020-12-12 05:25:37.txt
#
#
# Saving file 211_452 ...
# Saved JSON: /common/home/milky-way/cities/211_452.txt
#
# Saving image 211_451 ...
# Saved image: /common/home/milky-way/output_images/211_451.png
# Processing:  2020-12-12 05:25:36.txt
#
#
# Saving file 211_451 ...
# Saved JSON: /common/home/milky-way/cities/211_451.txt
#
# Saving image 211_450 ...
# Saved image: /common/home/milky-way/output_images/211_450.png
# Processing:  2020-12-12 05:25:35.txt
#
#
# Saving file 211_450 ...
# Saved JSON: /common/home/milky-way/cities/211_450.txt
#
# Saving image 211_449 ...
# Saved image: /common/home/milky-way/output_images/211_449.png
# Processing:  2020-12-12 05:25:33.txt
#
#
# Saving file 211_449 ...
# Saved JSON: /common/home/milky-way/cities/211_449.txt
#
# Saving image 211_448 ...
# Saved image: /common/home/milky-way/output_images/211_448.png
# Processing:  2020-12-12 05:25:32.txt
#
#
# Saving file 211_448 ...
# Saved JSON: /common/home/milky-way/cities/211_448.txt
#
# Saving image 211_447 ...
# Saved image: /common/home/milky-way/output_images/211_447.png
# Processing:  2020-12-12 05:25:28.txt
#
#
# Saving file 211_447 ...
# Saved JSON: /common/home/milky-way/cities/211_447.txt
#
# Saving image 211_446 ...
# Saved image: /common/home/milky-way/output_images/211_446.png
# Processing:  2020-12-12 05:25:26.txt
#
#
# Saving file 211_446 ...
# Saved JSON: /common/home/milky-way/cities/211_446.txt
#
# Saving image 211_445 ...
# Saved image: /common/home/milky-way/output_images/211_445.png
# Processing:  2020-12-12 05:25:22.txt
#
#
# Saving file 211_445 ...
# Saved JSON: /common/home/milky-way/cities/211_445.txt
#
# Saving image 211_444 ...
# Saved image: /common/home/milky-way/output_images/211_444.png
# Processing:  2020-12-12 05:25:21.txt
#
#
# Saving file 211_444 ...
# Saved JSON: /common/home/milky-way/cities/211_444.txt
#
# Saving image 211_443 ...
# Saved image: /common/home/milky-way/output_images/211_443.png
# Processing:  2020-12-12 05:25:16.txt
#
#
# Saving file 211_443 ...
# Saved JSON: /common/home/milky-way/cities/211_443.txt
#
# Saving image 211_442 ...
# Saved image: /common/home/milky-way/output_images/211_442.png
# Processing:  2020-12-12 05:25:15.txt
#
#
# Saving file 211_442 ...
# Saved JSON: /common/home/milky-way/cities/211_442.txt
#
# Saving image 211_441 ...
# Saved image: /common/home/milky-way/output_images/211_441.png
# Processing:  2020-12-12 05:25:13.txt
#
#
# Saving file 211_441 ...
# Saved JSON: /common/home/milky-way/cities/211_441.txt
#
# Saving image 211_440 ...
# Saved image: /common/home/milky-way/output_images/211_440.png
# Processing:  2020-12-12 05:25:10.txt
#
#
# Saving file 211_440 ...
# Saved JSON: /common/home/milky-way/cities/211_440.txt
#
# Saving image 211_439 ...
# Saved image: /common/home/milky-way/output_images/211_439.png
# Processing:  2020-12-12 05:25:08.txt
#
#
# Saving file 211_439 ...
# Saved JSON: /common/home/milky-way/cities/211_439.txt
#
# Saving image 211_438 ...
# Saved image: /common/home/milky-way/output_images/211_438.png
# Processing:  2020-12-12 05:25:05.txt
#
#
# Saving file 211_438 ...
# Saved JSON: /common/home/milky-way/cities/211_438.txt
#
# Saving image 211_437 ...
# Saved image: /common/home/milky-way/output_images/211_437.png
# Processing:  2020-12-12 05:25:02.txt
#
#
# Saving file 211_437 ...
# Saved JSON: /common/home/milky-way/cities/211_437.txt
#
# Saving image 211_436 ...
# Saved image: /common/home/milky-way/output_images/211_436.png
# Processing:  2020-12-12 05:24:59.txt
#
#
# Saving file 211_436 ...
# Saved JSON: /common/home/milky-way/cities/211_436.txt
#
# Saving image 211_435 ...
# Saved image: /common/home/milky-way/output_images/211_435.png
# Processing:  2020-12-12 05:24:58.txt
#
#
# Saving file 211_435 ...
# Saved JSON: /common/home/milky-way/cities/211_435.txt
#
# Saving image 211_434 ...
# Saved image: /common/home/milky-way/output_images/211_434.png
# Processing:  2020-12-12 05:24:57.txt
#
#
# Saving file 211_434 ...
# Saved JSON: /common/home/milky-way/cities/211_434.txt
#
# Saving image 211_433 ...
# Saved image: /common/home/milky-way/output_images/211_433.png
# Processing:  2020-12-12 05:24:52.txt
#
#
# Saving file 211_433 ...
# Saved JSON: /common/home/milky-way/cities/211_433.txt
#
# Saving image 211_432 ...
# Saved image: /common/home/milky-way/output_images/211_432.png
# Processing:  2020-12-12 05:24:50.txt
#
#
# Saving file 211_432 ...
# Saved JSON: /common/home/milky-way/cities/211_432.txt
#
# Saving image 209_499 ...
# Saved image: /common/home/milky-way/output_images/209_499.png
# Processing:  2020-12-12 05:22:07.txt
#
#
# Saving file 209_499 ...
# Saved JSON: /common/home/milky-way/cities/209_499.txt
#
# Saving image 209_498 ...
# Saved image: /common/home/milky-way/output_images/209_498.png
# Processing:  2020-12-12 05:22:05.txt
#
#
# Saving file 209_498 ...
# Saved JSON: /common/home/milky-way/cities/209_498.txt
#
# Saving image 209_497 ...
# Saved image: /common/home/milky-way/output_images/209_497.png
# Processing:  2020-12-12 05:21:57.txt
#
#
# Saving file 209_497 ...
# Saved JSON: /common/home/milky-way/cities/209_497.txt
#
# Saving image 209_496 ...
# Saved image: /common/home/milky-way/output_images/209_496.png
# Processing:  2020-12-12 05:21:53.txt
#
#
# Saving file 209_496 ...
# Saved JSON: /common/home/milky-way/cities/209_496.txt
#
# Saving image 209_495 ...
# Saved image: /common/home/milky-way/output_images/209_495.png
# Processing:  2020-12-12 05:21:46.txt
#
#
# Saving file 209_495 ...
# Saved JSON: /common/home/milky-way/cities/209_495.txt
#
# Saving image 209_494 ...
# Saved image: /common/home/milky-way/output_images/209_494.png
# Processing:  2020-12-12 05:21:43.txt
#
#
# Saving file 209_494 ...
# Saved JSON: /common/home/milky-way/cities/209_494.txt
#
# Saving image 209_493 ...
# Saved image: /common/home/milky-way/output_images/209_493.png
# Processing:  2020-12-12 05:21:42.txt
#
#
# Saving file 209_493 ...
# Saved JSON: /common/home/milky-way/cities/209_493.txt
#
# Saving image 209_492 ...
# Saved image: /common/home/milky-way/output_images/209_492.png
# Processing:  2020-12-12 05:21:26.txt
#
#
# Saving file 209_492 ...
# Saved JSON: /common/home/milky-way/cities/209_492.txt
#
# Saving image 209_491 ...
# Saved image: /common/home/milky-way/output_images/209_491.png
# Processing:  2020-12-12 05:21:20.txt
#
#
# Saving file 209_491 ...
# Saved JSON: /common/home/milky-way/cities/209_491.txt
#
# Saving image 209_490 ...
# Saved image: /common/home/milky-way/output_images/209_490.png
# Processing:  2020-12-12 05:21:12.txt
#
#
# Saving file 209_490 ...
# Saved JSON: /common/home/milky-way/cities/209_490.txt
#
# Saving image 209_489 ...
# Saved image: /common/home/milky-way/output_images/209_489.png
# Processing:  2020-12-12 05:20:58.txt
#
#
# Saving file 209_489 ...
# Saved JSON: /common/home/milky-way/cities/209_489.txt
#
# Saving image 209_488 ...
# Saved image: /common/home/milky-way/output_images/209_488.png
# Processing:  2020-12-12 05:20:53.txt
#
#
# Saving file 209_488 ...
# Saved JSON: /common/home/milky-way/cities/209_488.txt
#
# Saving image 209_487 ...
# Saved image: /common/home/milky-way/output_images/209_487.png
# Processing:  2020-12-12 05:20:49.txt
#
#
# Saving file 209_487 ...
# Saved JSON: /common/home/milky-way/cities/209_487.txt
#
# Saving image 209_486 ...
# Saved image: /common/home/milky-way/output_images/209_486.png
# Processing:  2020-12-12 05:20:47.txt
#
#
# Saving file 209_486 ...
# Saved JSON: /common/home/milky-way/cities/209_486.txt
#
# Saving image 209_485 ...
# Saved image: /common/home/milky-way/output_images/209_485.png
# Processing:  2020-12-12 05:20:45.txt
#
#
# Saving file 209_485 ...
# Saved JSON: /common/home/milky-way/cities/209_485.txt
#
# Saving image 209_484 ...
# Saved image: /common/home/milky-way/output_images/209_484.png
# Processing:  2020-12-12 05:20:44.txt
#
#
# Saving file 209_484 ...
# Saved JSON: /common/home/milky-way/cities/209_484.txt
#
# Saving image 209_483 ...
# Saved image: /common/home/milky-way/output_images/209_483.png
# Processing:  2020-12-12 05:20:34.txt
#
#
# Saving file 209_483 ...
# Saved JSON: /common/home/milky-way/cities/209_483.txt
#
# Saving image 209_482 ...
# Saved image: /common/home/milky-way/output_images/209_482.png
# Processing:  2020-12-12 05:20:26.txt
#
#
# Saving file 209_482 ...
# Saved JSON: /common/home/milky-way/cities/209_482.txt
#
# Saving image 209_481 ...
# Saved image: /common/home/milky-way/output_images/209_481.png
# Processing:  2020-12-12 05:20:16.txt
#
#
# Saving file 209_481 ...
# Saved JSON: /common/home/milky-way/cities/209_481.txt
#
# Saving image 209_480 ...
# Saved image: /common/home/milky-way/output_images/209_480.png
# Processing:  2020-12-12 05:20:13.txt
#
#
# Saving file 209_480 ...
# Saved JSON: /common/home/milky-way/cities/209_480.txt
#
# Saving image 209_479 ...
# Saved image: /common/home/milky-way/output_images/209_479.png
# Processing:  2020-12-12 05:20:03.txt
#
#
# Saving file 209_479 ...
# Saved JSON: /common/home/milky-way/cities/209_479.txt
#
# Saving image 209_478 ...
# Saved image: /common/home/milky-way/output_images/209_478.png
# Processing:  2020-12-12 05:19:58.txt
#
#
# Saving file 209_478 ...
# Saved JSON: /common/home/milky-way/cities/209_478.txt
#
# Saving image 209_477 ...
# Saved image: /common/home/milky-way/output_images/209_477.png
# Processing:  2020-12-12 05:19:47.txt
#
#
# Saving file 209_477 ...
# Saved JSON: /common/home/milky-way/cities/209_477.txt
#
# Saving image 209_476 ...
# Saved image: /common/home/milky-way/output_images/209_476.png
# Processing:  2020-12-12 05:19:46.txt
#
#
# Saving file 209_476 ...
# Saved JSON: /common/home/milky-way/cities/209_476.txt
#
# Saving image 208_425 ...
# Saved image: /common/home/milky-way/output_images/208_425.png
# Processing:  2020-12-12 05:19:39.txt
#
#
# Saving file 208_425 ...
# Saved JSON: /common/home/milky-way/cities/208_425.txt
#
# Saving image 208_424 ...
# Saved image: /common/home/milky-way/output_images/208_424.png
# Processing:  2020-12-12 05:19:35.txt
#
#
# Saving file 208_424 ...
# Saved JSON: /common/home/milky-way/cities/208_424.txt
#
# Saving image 208_423 ...
# Saved image: /common/home/milky-way/output_images/208_423.png
# Processing:  2020-12-12 05:19:34.txt
#
#
# Saving file 208_423 ...
# Saved JSON: /common/home/milky-way/cities/208_423.txt
#
# Saving image 208_422 ...
# Saved image: /common/home/milky-way/output_images/208_422.png
# Processing:  2020-12-12 05:19:32.txt
#
#
# Saving file 208_422 ...
# Saved JSON: /common/home/milky-way/cities/208_422.txt
#
# Saving image 208_421 ...
# Saved image: /common/home/milky-way/output_images/208_421.png
# Processing:  2020-12-12 05:19:30.txt
#
#
# Saving file 208_421 ...
# Saved JSON: /common/home/milky-way/cities/208_421.txt
#
# Saving image 208_420 ...
# Saved image: /common/home/milky-way/output_images/208_420.png
# Processing:  2020-12-12 05:19:26.txt
#
#
# Saving file 208_420 ...
# Saved JSON: /common/home/milky-way/cities/208_420.txt
#
# Saving image 208_419 ...
# Saved image: /common/home/milky-way/output_images/208_419.png
# Processing:  2020-12-12 05:19:25.txt
#
#
# Saving file 208_419 ...
# Saved JSON: /common/home/milky-way/cities/208_419.txt
#
# Saving image 208_418 ...
# Saved image: /common/home/milky-way/output_images/208_418.png
# Processing:  2020-12-12 05:19:19.txt
#
#
# Saving file 208_418 ...
# Saved JSON: /common/home/milky-way/cities/208_418.txt
#
# Saving image 208_417 ...
# Saved image: /common/home/milky-way/output_images/208_417.png
# Processing:  2020-12-12 05:19:16.txt
#
#
# Saving file 208_417 ...
# Saved JSON: /common/home/milky-way/cities/208_417.txt
#
# Saving image 208_416 ...
# Saved image: /common/home/milky-way/output_images/208_416.png
# Processing:  2020-12-12 05:19:07.txt
#
#
# Saving file 208_416 ...
# Saved JSON: /common/home/milky-way/cities/208_416.txt
#
# Saving image 208_415 ...
# Saved image: /common/home/milky-way/output_images/208_415.png
# Processing:  2020-12-12 05:19:04.txt
#
#
# Saving file 208_415 ...
# Saved JSON: /common/home/milky-way/cities/208_415.txt
#
# Saving image 208_414 ...
# Saved image: /common/home/milky-way/output_images/208_414.png
# Processing:  2020-12-12 05:19:03.txt
#
#
# Saving file 208_414 ...
# Saved JSON: /common/home/milky-way/cities/208_414.txt
#
# Saving image 208_413 ...
# Saved image: /common/home/milky-way/output_images/208_413.png
# Processing:  2020-12-12 05:19:02.txt
#
#
# Saving file 208_413 ...
# Saved JSON: /common/home/milky-way/cities/208_413.txt
#
# Saving image 208_412 ...
# Saved image: /common/home/milky-way/output_images/208_412.png
# Processing:  2020-12-12 05:18:58.txt
#
#
# Saving file 208_412 ...
# Saved JSON: /common/home/milky-way/cities/208_412.txt
#
# Saving image 208_411 ...
# Saved image: /common/home/milky-way/output_images/208_411.png
# Processing:  2020-12-12 05:18:55.txt
#
#
# Saving file 208_411 ...
# Saved JSON: /common/home/milky-way/cities/208_411.txt
#
# Saving image 208_410 ...
# Saved image: /common/home/milky-way/output_images/208_410.png
# Processing:  2020-12-12 05:18:53.txt
#
#
# Saving file 208_410 ...
# Saved JSON: /common/home/milky-way/cities/208_410.txt
#
# Saving image 208_409 ...
# Saved image: /common/home/milky-way/output_images/208_409.png
# Processing:  2020-12-12 05:18:52.txt
#
#
# Saving file 208_409 ...
# Saved JSON: /common/home/milky-way/cities/208_409.txt
#
# Saving image 208_408 ...
# Saved image: /common/home/milky-way/output_images/208_408.png
# Processing:  2020-12-12 05:18:51.txt
#
#
# Saving file 208_408 ...
# Saved JSON: /common/home/milky-way/cities/208_408.txt
#
# Saving image 208_407 ...
# Saved image: /common/home/milky-way/output_images/208_407.png
# Processing:  2020-12-12 05:18:50.txt
#
#
# Saving file 208_407 ...
# Saved JSON: /common/home/milky-way/cities/208_407.txt
#
# Saving image 208_406 ...
# Saved image: /common/home/milky-way/output_images/208_406.png
# Processing:  2020-12-12 05:18:49.txt
#
#
# Saving file 208_406 ...
# Saved JSON: /common/home/milky-way/cities/208_406.txt
#
# Saving image 208_405 ...
# Saved image: /common/home/milky-way/output_images/208_405.png
# Processing:  2020-12-12 05:18:48.txt
#
#
# Saving file 208_405 ...
# Saved JSON: /common/home/milky-way/cities/208_405.txt
#
# Saving image 208_404 ...
# Saved image: /common/home/milky-way/output_images/208_404.png
# Processing:  2020-12-12 05:18:47.txt
#
#
# Saving file 208_404 ...
# Saved JSON: /common/home/milky-way/cities/208_404.txt
#
# Saving image 208_403 ...
# Saved image: /common/home/milky-way/output_images/208_403.png
# Processing:  2020-12-12 05:18:46.txt
#
#
# Saving file 208_403 ...
# Saved JSON: /common/home/milky-way/cities/208_403.txt
#
# Saving image 208_402 ...
# Saved image: /common/home/milky-way/output_images/208_402.png
# Processing:  2020-12-12 05:18:45.txt
#
#
# Saving file 208_402 ...
# Saved JSON: /common/home/milky-way/cities/208_402.txt
#
# Saving image 208_401 ...
# Saved image: /common/home/milky-way/output_images/208_401.png
# Processing:  2020-12-12 05:18:43.txt
#
#
# Saving file 208_401 ...
# Saved JSON: /common/home/milky-way/cities/208_401.txt
#
# Saving image 208_400 ...
# Saved image: /common/home/milky-way/output_images/208_400.png
# Processing:  2020-12-12 05:18:42.txt
#
#
# Saving file 208_400 ...
# Saved JSON: /common/home/milky-way/cities/208_400.txt
#
# Saving image 208_399 ...
# Saved image: /common/home/milky-way/output_images/208_399.png
# Processing:  2020-12-12 05:18:41.txt
#
#
# Saving file 208_399 ...
# Saved JSON: /common/home/milky-way/cities/208_399.txt
#
# Saving image 208_398 ...
# Saved image: /common/home/milky-way/output_images/208_398.png
# Processing:  2020-12-12 05:18:40.txt
#
#
# Saving file 208_398 ...
# Saved JSON: /common/home/milky-way/cities/208_398.txt
#
# Saving image 208_397 ...
# Saved image: /common/home/milky-way/output_images/208_397.png
# Processing:  2020-12-12 05:18:39.txt
#
#
# Saving file 208_397 ...
# Saved JSON: /common/home/milky-way/cities/208_397.txt
#
# Saving image 208_396 ...
# Saved image: /common/home/milky-way/output_images/208_396.png
# Processing:  2020-12-12 05:18:38.txt
#
#
# Saving file 208_396 ...
# Saved JSON: /common/home/milky-way/cities/208_396.txt
#
# Saving image 208_395 ...
# Saved image: /common/home/milky-way/output_images/208_395.png
# Processing:  2020-12-12 05:18:37.txt
#
#
# Saving file 208_395 ...
# Saved JSON: /common/home/milky-way/cities/208_395.txt
#
# Saving image 208_394 ...
# Saved image: /common/home/milky-way/output_images/208_394.png
# Processing:  2020-12-12 05:18:36.txt
#
#
# Saving file 208_394 ...
# Saved JSON: /common/home/milky-way/cities/208_394.txt
#
# Saving image 208_393 ...
# Saved image: /common/home/milky-way/output_images/208_393.png
# Processing:  2020-12-12 05:18:35.txt
#
#
# Saving file 208_393 ...
# Saved JSON: /common/home/milky-way/cities/208_393.txt
#
# Saving image 208_392 ...
# Saved image: /common/home/milky-way/output_images/208_392.png
# Processing:  2020-12-12 05:18:34.txt
#
#
# Saving file 208_392 ...
# Saved JSON: /common/home/milky-way/cities/208_392.txt
#
# Saving image 208_391 ...
# Saved image: /common/home/milky-way/output_images/208_391.png
# Processing:  2020-12-12 05:18:29.txt
#
#
# Saving file 208_391 ...
# Saved JSON: /common/home/milky-way/cities/208_391.txt
#
# Saving image 208_390 ...
# Saved image: /common/home/milky-way/output_images/208_390.png
# Processing:  2020-12-12 05:18:28.txt
#
#
# Saving file 208_390 ...
# Saved JSON: /common/home/milky-way/cities/208_390.txt
#
# Saving image 208_389 ...
# Saved image: /common/home/milky-way/output_images/208_389.png
# Processing:  2020-12-12 05:18:27.txt
#
#
# Saving file 208_389 ...
# Saved JSON: /common/home/milky-way/cities/208_389.txt
#
# Saving image 208_388 ...
# Saved image: /common/home/milky-way/output_images/208_388.png
# Processing:  2020-12-12 05:18:26.txt
#
#
# Saving file 208_388 ...
# Saved JSON: /common/home/milky-way/cities/208_388.txt
#
# Saving image 208_387 ...
# Saved image: /common/home/milky-way/output_images/208_387.png
# Processing:  2020-12-12 05:18:24.txt
#
#
# Saving file 208_387 ...
# Saved JSON: /common/home/milky-way/cities/208_387.txt
#
# Saving image 208_386 ...
# Saved image: /common/home/milky-way/output_images/208_386.png
# Processing:  2020-12-12 05:18:23.txt
#
#
# Saving file 208_386 ...
# Saved JSON: /common/home/milky-way/cities/208_386.txt
#
# Saving image 208_385 ...
# Saved image: /common/home/milky-way/output_images/208_385.png
# Processing:  2020-12-12 05:18:22.txt
#
#
# Saving file 208_385 ...
# Saved JSON: /common/home/milky-way/cities/208_385.txt
#
# Saving image 208_384 ...
# Saved image: /common/home/milky-way/output_images/208_384.png
# Processing:  2020-12-12 05:18:21.txt
#
#
# Saving file 208_384 ...
# Saved JSON: /common/home/milky-way/cities/208_384.txt
#
# Saving image 208_383 ...
# Saved image: /common/home/milky-way/output_images/208_383.png
# Processing:  2020-12-12 05:18:19.txt
#
#
# Saving file 208_383 ...
# Saved JSON: /common/home/milky-way/cities/208_383.txt
#
# Saving image 208_382 ...
# Saved image: /common/home/milky-way/output_images/208_382.png
# Processing:  2020-12-12 05:18:17.txt
#
#
# Saving file 208_382 ...
# Saved JSON: /common/home/milky-way/cities/208_382.txt
#
# Saving image 208_381 ...
# Saved image: /common/home/milky-way/output_images/208_381.png
# Processing:  2020-12-12 05:18:14.txt
#
#
# Saving file 208_381 ...
# Saved JSON: /common/home/milky-way/cities/208_381.txt
#
# Saving image 208_380 ...
# Saved image: /common/home/milky-way/output_images/208_380.png
# Processing:  2020-12-12 05:18:13.txt
#
#
# Saving file 208_380 ...
# Saved JSON: /common/home/milky-way/cities/208_380.txt
#
# Saving image 208_379 ...
# Saved image: /common/home/milky-way/output_images/208_379.png
# Processing:  2020-12-12 05:18:11.txt
#
#
# Saving file 208_379 ...
# Saved JSON: /common/home/milky-way/cities/208_379.txt
#
# Saving image 208_378 ...
# Saved image: /common/home/milky-way/output_images/208_378.png
# Processing:  2020-12-12 05:18:08.txt
#
#
# Saving file 208_378 ...
# Saved JSON: /common/home/milky-way/cities/208_378.txt
#
# Saving image 208_377 ...
# Saved image: /common/home/milky-way/output_images/208_377.png
# Processing:  2020-12-12 05:18:05.txt
#
#
# Saving file 208_377 ...
# Saved JSON: /common/home/milky-way/cities/208_377.txt
#
# Saving image 208_376 ...
# Saved image: /common/home/milky-way/output_images/208_376.png
# Processing:  2020-12-12 05:18:04.txt
#
#
# Saving file 208_376 ...
# Saved JSON: /common/home/milky-way/cities/208_376.txt
#
# Saving image 208_375 ...
# Saved image: /common/home/milky-way/output_images/208_375.png
# Processing:  2020-12-12 05:18:03.txt
#
#
# Saving file 208_375 ...
# Saved JSON: /common/home/milky-way/cities/208_375.txt
#
# Saving image 208_374 ...
# Saved image: /common/home/milky-way/output_images/208_374.png
# Processing:  2020-12-12 05:18:02.txt
#
#
# Saving file 208_374 ...
# Saved JSON: /common/home/milky-way/cities/208_374.txt
#
# Saving image 208_373 ...
# Saved image: /common/home/milky-way/output_images/208_373.png
# Processing:  2020-12-12 05:18:01.txt
#
#
# Saving file 208_373 ...
# Saved JSON: /common/home/milky-way/cities/208_373.txt
#
# Saving image 208_372 ...
# Saved image: /common/home/milky-way/output_images/208_372.png
# Processing:  2020-12-12 05:17:59.txt
#
#
# Saving file 208_372 ...
# Saved JSON: /common/home/milky-way/cities/208_372.txt
#
# Saving image 208_371 ...

# %%
"""
Files to ignore in temp:

'2020-12-12 14:05:06.txt'
'2020-12-12 14:05:07.txt'
'2020-12-12 14:05:09.txt'

"""

# %%
a = {1:"a"}
"a" in a
